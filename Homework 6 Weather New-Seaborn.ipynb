# %%
#Dependencies
import seaborn as sns
iris = sns.load_dataset('iris')
from citipy import citipy
from config import api_key
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
#Random generate latitude and longitude numbers then lookup nearest city using citipy

# Empty series to hold names of cities and countries
randCity = []
randCountry = []
loopcnt = 0

#Loop through untill 500 unique city names are found
#increase to 750. len is 438 using 500!
while len(randCity) < 750 :
    # Loop counter just to track number of loops made
    loopcnt +=1
    
    # Random generate latitude
    lat_pos = random.randint(0,2)
    base_lat = random.randint(0,91)
    dec_lat = random.random()/100
    lat = base_lat + dec_lat
    if lat_pos == 1:
        lat = lat * -1
    #print(f"The lattitude is: {lat}") 
    
    # Random generate longitude
    lng_pos = random.randint(0,2)
    base_lng = random.randint(0,181)
    dec_lng = random.random()/100
    lng = base_lng + dec_lng
    if lng_pos == 1:
        lng = lng * -1
    #print(f"The longitude is: {lng}") 
    
    # Call citipy to get nearest city based on random lat and lng
    city = citipy.nearest_city(lat, lng)
    
    # Test to see if the random city is already in the list, if not, add to the city and country lists
    foundCity = False
    for j in range(len(randCity)):
        if city.city_name == randCity[j]:
            foundCity = True
    if foundCity==False  :   
        randCity.append(city.city_name)
        randCountry.append(city.country_code)

# %%
# Build query Url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = api_key
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="

# %%
# Loop through the list of cities and perform a request for data on each
search_data = []
cityList = []
countryList = []

searchCnt = 0
print("Start API Call to OpenWeather Database ")
print("---------------------------------------")
for city in randCity:
    searchCnt += 1
    print(f"Processing record {searchCnt} for the city: {city}")   
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
    if response.get("id"):
        print(f"     Record found for city: {city}    city id: {searchCityID}")
        search_data.append(response)
        cityList.append(city)
        countryList.append(randCountry[searchCnt-1])
    else:
        print(f"     No weather record found for city: {city}")
          
print("---------------------------------------")
print("End")
# Out:
# Start API Call to OpenWeather Database
# ---------------------------------------
# Processing record 1 for the city: wloszczowa
#      Record found for city: wloszczowa    city id: 3081699
# Processing record 2 for the city: tautira
#      Record found for city: tautira    city id: 4033557
# Processing record 3 for the city: saint george
#      Record found for city: saint george    city id: 262462
# Processing record 4 for the city: lorengau
#      Record found for city: lorengau    city id: 2092164
# Processing record 5 for the city: bengkulu
#      No weather record found for city: bengkulu
# Processing record 6 for the city: victoria
#      Record found for city: victoria    city id: 1733782
# Processing record 7 for the city: brae
#      Record found for city: brae    city id: 2654970
# Processing record 8 for the city: wanaka
#      Record found for city: wanaka    city id: 2184707
# Processing record 9 for the city: kodiak
#      Record found for city: kodiak    city id: 4407665
# Processing record 10 for the city: tiznit
#      Record found for city: tiznit    city id: 2527089
# Processing record 11 for the city: iqaluit
#      Record found for city: iqaluit    city id: 5983720
# Processing record 12 for the city: mount gambier
#      Record found for city: mount gambier    city id: 2156643
# Processing record 13 for the city: magadan
#      Record found for city: magadan    city id: 2123628
# Processing record 14 for the city: faya
#      Record found for city: faya    city id: 110690
# Processing record 15 for the city: ushuaia
#      Record found for city: ushuaia    city id: 3833367
# Processing record 16 for the city: ribeira grande
#      Record found for city: ribeira grande    city id: 3372707
# Processing record 17 for the city: fomboni
#      Record found for city: fomboni    city id: 921889
# Processing record 18 for the city: flinders
#      Record found for city: flinders    city id: 6255012
# Processing record 19 for the city: tommot
#      Record found for city: tommot    city id: 2015179
# Processing record 20 for the city: saskylakh
#      Record found for city: saskylakh    city id: 2017155
# Processing record 21 for the city: tura
#      Record found for city: tura    city id: 1254046
# Processing record 22 for the city: ponta do sol
#      Record found for city: ponta do sol    city id: 3453439
# Processing record 23 for the city: bijar
#      Record found for city: bijar    city id: 140521
# Processing record 24 for the city: kiunga
#      Record found for city: kiunga    city id: 2093846
# Processing record 25 for the city: komsomolskiy
#      Record found for city: komsomolskiy    city id: 1486910
# Processing record 26 for the city: jumla
#      Record found for city: jumla    city id: 1283285
# Processing record 27 for the city: malpe
#      Record found for city: malpe    city id: 1264037
# Processing record 28 for the city: turka
#      Record found for city: turka    city id: 690960
# Processing record 29 for the city: lahij
#      Record found for city: lahij    city id: 73560
# Processing record 30 for the city: kismayo
#      No weather record found for city: kismayo
# Processing record 31 for the city: sungaipenuh
#      Record found for city: sungaipenuh    city id: 1625929
# Processing record 32 for the city: pevek
#      Record found for city: pevek    city id: 2122090
# Processing record 33 for the city: panjab
#      Record found for city: panjab    city id: 1131162
# Processing record 34 for the city: trincomalee
#      Record found for city: trincomalee    city id: 1226260
# Processing record 35 for the city: severo-kurilsk
#      Record found for city: severo-kurilsk    city id: 2121385
# Processing record 36 for the city: katsuura
#      Record found for city: katsuura    city id: 1865309
# Processing record 37 for the city: cape town
#      Record found for city: cape town    city id: 3369157
# Processing record 38 for the city: ahero
#      Record found for city: ahero    city id: 201229
# Processing record 39 for the city: dolores
#      Record found for city: dolores    city id: 3435038
# Processing record 40 for the city: kampong thum
#      Record found for city: kampong thum    city id: 1831125
# Processing record 41 for the city: oeiras
#      Record found for city: oeiras    city id: 3393764
# Processing record 42 for the city: yerky
#      Record found for city: yerky    city id: 701075
# Processing record 43 for the city: marcona
#      No weather record found for city: marcona
# Processing record 44 for the city: hasaki
#      Record found for city: hasaki    city id: 2112802
# Processing record 45 for the city: nizhneyansk
#      No weather record found for city: nizhneyansk
# Processing record 46 for the city: sorel
#      Record found for city: sorel    city id: 6151350
# Processing record 47 for the city: port alfred
#      Record found for city: port alfred    city id: 964432
# Processing record 48 for the city: arman
#      Record found for city: arman    city id: 2127060
# Processing record 49 for the city: belushya guba
#      No weather record found for city: belushya guba
# Processing record 50 for the city: bairiki
#      No weather record found for city: bairiki
# Processing record 51 for the city: seoul
#      Record found for city: seoul    city id: 1835848
# Processing record 52 for the city: lata
#      Record found for city: lata    city id: 1253628
# Processing record 53 for the city: san cristobal
#      Record found for city: san cristobal    city id: 3652462
# Processing record 54 for the city: graaff-reinet
#      Record found for city: graaff-reinet    city id: 1000543
# Processing record 55 for the city: husavik
#      Record found for city: husavik    city id: 5961417
# Processing record 56 for the city: bredasdorp
#      Record found for city: bredasdorp    city id: 1015776
# Processing record 57 for the city: khatanga
#      Record found for city: khatanga    city id: 2022572
# Processing record 58 for the city: namibe
#      Record found for city: namibe    city id: 3347019
# Processing record 59 for the city: hilo
#      Record found for city: hilo    city id: 5855927
# Processing record 60 for the city: amderma
#      No weather record found for city: amderma
# Processing record 61 for the city: talnakh
#      Record found for city: talnakh    city id: 1490256
# Processing record 62 for the city: deh rawud
#      No weather record found for city: deh rawud
# Processing record 63 for the city: leningradskiy
#      Record found for city: leningradskiy    city id: 2123814
# Processing record 64 for the city: lerwick
#      Record found for city: lerwick    city id: 2644605
# Processing record 65 for the city: thompson
#      Record found for city: thompson    city id: 6165406
# Processing record 66 for the city: sao gabriel da cachoeira
#      Record found for city: sao gabriel da cachoeira    city id: 3662342
# Processing record 67 for the city: alice springs
#      Record found for city: alice springs    city id: 2077895
# Processing record 68 for the city: qaanaaq
#      Record found for city: qaanaaq    city id: 3831208
# Processing record 69 for the city: dikson
#      Record found for city: dikson    city id: 1507390
# Processing record 70 for the city: tasiilaq
#      Record found for city: tasiilaq    city id: 3424607
# Processing record 71 for the city: taolanaro
#      No weather record found for city: taolanaro
# Processing record 72 for the city: mataura
#      Record found for city: mataura    city id: 6201424
# Processing record 73 for the city: yellowknife
#      Record found for city: yellowknife    city id: 6185377
# Processing record 74 for the city: fortuna
#      Record found for city: fortuna    city id: 2517679
# Processing record 75 for the city: feltre
#      Record found for city: feltre    city id: 3177120
# Processing record 76 for the city: belyy yar
#      Record found for city: belyy yar    city id: 1510377
# Processing record 77 for the city: mahebourg
#      Record found for city: mahebourg    city id: 934322
# Processing record 78 for the city: yerbogachen
#      Record found for city: yerbogachen    city id: 2012956
# Processing record 79 for the city: albany
#      Record found for city: albany    city id: 5106834
# Processing record 80 for the city: geraldton
#      Record found for city: geraldton    city id: 5960603
# Processing record 81 for the city: ruatoria
#      No weather record found for city: ruatoria
# Processing record 82 for the city: busselton
#      Record found for city: busselton    city id: 2075265
# Processing record 83 for the city: basco
#      Record found for city: basco    city id: 4863349
# Processing record 84 for the city: butaritari
#      Record found for city: butaritari    city id: 2110227
# Processing record 85 for the city: tulun
#      Record found for city: tulun    city id: 2014927
# Processing record 86 for the city: koumac
#      Record found for city: koumac    city id: 2140558
# Processing record 87 for the city: mahudha
#      Record found for city: mahudha    city id: 1264344
# Processing record 88 for the city: constitucion
#      Record found for city: constitucion    city id: 4011743
# Processing record 89 for the city: bluff
#      Record found for city: bluff    city id: 2175403
# Processing record 90 for the city: barrow
#      Record found for city: barrow    city id: 3833859
# Processing record 91 for the city: puerto ayora
#      Record found for city: puerto ayora    city id: 3652764
# Processing record 92 for the city: voyvozh
#      Record found for city: voyvozh    city id: 471308
# Processing record 93 for the city: punta arenas
#      Record found for city: punta arenas    city id: 3874787
# Processing record 94 for the city: roald
#      Record found for city: roald    city id: 3141667
# Processing record 95 for the city: louis trichardt
#      Record found for city: louis trichardt    city id: 981827
# Processing record 96 for the city: port blair
#      Record found for city: port blair    city id: 1259385
# Processing record 97 for the city: sorong
#      Record found for city: sorong    city id: 1626542
# Processing record 98 for the city: new norfolk
#      Record found for city: new norfolk    city id: 2155415
# Processing record 99 for the city: baykit
#      Record found for city: baykit    city id: 1510689
# Processing record 100 for the city: isangel
#      Record found for city: isangel    city id: 2136825
# Processing record 101 for the city: vardo
#      Record found for city: vardo    city id: 4372777
# Processing record 102 for the city: bethel
#      Record found for city: bethel    city id: 5880568
# Processing record 103 for the city: ugoofaaru
#      Record found for city: ugoofaaru    city id: 1337619
# Processing record 104 for the city: sentyabrskiy
#      No weather record found for city: sentyabrskiy
# Processing record 105 for the city: souillac
#      Record found for city: souillac    city id: 3026644
# Processing record 106 for the city: atar
#      Record found for city: atar    city id: 2381334
# Processing record 107 for the city: upernavik
#      Record found for city: upernavik    city id: 3418910
# Processing record 108 for the city: praia da vitoria
#      Record found for city: praia da vitoria    city id: 3372760
# Processing record 109 for the city: saint anthony
#      Record found for city: saint anthony    city id: 5606187
# Processing record 110 for the city: bodden town
#      Record found for city: bodden town    city id: 3580733
# Processing record 111 for the city: banda aceh
#      Record found for city: banda aceh    city id: 1215502
# Processing record 112 for the city: san quintin
#      Record found for city: san quintin    city id: 1688687
# Processing record 113 for the city: ereymentau
#      Record found for city: ereymentau    city id: 1524302
# Processing record 114 for the city: zachagansk
#      No weather record found for city: zachagansk
# Processing record 115 for the city: sedelnikovo
#      No weather record found for city: sedelnikovo
# Processing record 116 for the city: atuona
#      Record found for city: atuona    city id: 4020109
# Processing record 117 for the city: kavaratti
#      Record found for city: kavaratti    city id: 1267390
# Processing record 118 for the city: kahului
#      Record found for city: kahului    city id: 5847411
# Processing record 119 for the city: chegdomyn
#      Record found for city: chegdomyn    city id: 2025579
# Processing record 120 for the city: port elizabeth
#      Record found for city: port elizabeth    city id: 4501427
# Processing record 121 for the city: paradwip
#      No weather record found for city: paradwip
# Processing record 122 for the city: guerrero negro
#      Record found for city: guerrero negro    city id: 4021858
# Processing record 123 for the city: nikolskoye
#      Record found for city: nikolskoye    city id: 546105
# Processing record 124 for the city: tondano
#      Record found for city: tondano    city id: 1623424
# Processing record 125 for the city: kangaba
#      Record found for city: kangaba    city id: 2455735
# Processing record 126 for the city: jamestown
#      Record found for city: jamestown    city id: 2069194
# Processing record 127 for the city: sal rei
#      Record found for city: sal rei    city id: 3374235
# Processing record 128 for the city: keetmanshoop
#      Record found for city: keetmanshoop    city id: 3356264
# Processing record 129 for the city: norman wells
#      Record found for city: norman wells    city id: 6089245
# Processing record 130 for the city: rocha
#      Record found for city: rocha    city id: 3440777
# Processing record 131 for the city: saint-pierre
#      Record found for city: saint-pierre    city id: 2995603
# Processing record 132 for the city: andra
#      Record found for city: andra    city id: 1511646
# Processing record 133 for the city: anuchino
#      Record found for city: anuchino    city id: 2027596
# Processing record 134 for the city: wladyslawowo
#      Record found for city: wladyslawowo    city id: 3081752
# Processing record 135 for the city: phangnga
#      Record found for city: phangnga    city id: 1151464
# Processing record 136 for the city: vila franca do campo
#      Record found for city: vila franca do campo    city id: 3372472
# Processing record 137 for the city: barentsburg
#      No weather record found for city: barentsburg
# Processing record 138 for the city: georgetown
#      Record found for city: georgetown    city id: 3378644
# Processing record 139 for the city: mehndawal
#      Record found for city: mehndawal    city id: 1263185
# Processing record 140 for the city: adrar
#      Record found for city: adrar    city id: 2508813
# Processing record 141 for the city: qasigiannguit
#      Record found for city: qasigiannguit    city id: 3420768
# Processing record 142 for the city: ostrovnoy
#      Record found for city: ostrovnoy    city id: 556268
# Processing record 143 for the city: miri
#      Record found for city: miri    city id: 2347470
# Processing record 144 for the city: lolua
#      No weather record found for city: lolua
# Processing record 145 for the city: san jose
#      Record found for city: san jose    city id: 1689431
# Processing record 146 for the city: mackenzie
#      Record found for city: mackenzie    city id: 6063191
# Processing record 147 for the city: gerash
#      Record found for city: gerash    city id: 133595
# Processing record 148 for the city: carnarvon
#      Record found for city: carnarvon    city id: 1014034
# Processing record 149 for the city: rongcheng
#      Record found for city: rongcheng    city id: 1786855
# Processing record 150 for the city: hobart
#      Record found for city: hobart    city id: 2163355
# Processing record 151 for the city: samarai
#      Record found for city: samarai    city id: 2132606
# Processing record 152 for the city: dongsheng
#      Record found for city: dongsheng    city id: 1788268
# Processing record 153 for the city: tres arroyos
#      Record found for city: tres arroyos    city id: 3833859
# Processing record 154 for the city: namatanai
#      Record found for city: namatanai    city id: 2090021
# Processing record 155 for the city: mergui
#      No weather record found for city: mergui
# Processing record 156 for the city: vaini
#      Record found for city: vaini    city id: 1273574
# Processing record 157 for the city: yulara
#      Record found for city: yulara    city id: 6355222
# Processing record 158 for the city: khlevnoye
#      Record found for city: khlevnoye    city id: 471329
# Processing record 159 for the city: tumaco
#      Record found for city: tumaco    city id: 3666640
# Processing record 160 for the city: raton
#      Record found for city: raton    city id: 5486795
# Processing record 161 for the city: hunza
#      No weather record found for city: hunza
# Processing record 162 for the city: inhambane
#      Record found for city: inhambane    city id: 1045114
# Processing record 163 for the city: viramgam
#      Record found for city: viramgam    city id: 1270770
# Processing record 164 for the city: iskateley
#      Record found for city: iskateley    city id: 866062
# Processing record 165 for the city: sur
#      Record found for city: sur    city id: 286245
# Processing record 166 for the city: east london
#      Record found for city: east london    city id: 1006984
# Processing record 167 for the city: port augusta
#      Record found for city: port augusta    city id: 2063056
# Processing record 168 for the city: general pico
#      Record found for city: general pico    city id: 3855075
# Processing record 169 for the city: gat
#      Record found for city: gat    city id: 2249901
# Processing record 170 for the city: srednekolymsk
#      Record found for city: srednekolymsk    city id: 2121025
# Processing record 171 for the city: chokurdakh
#      Record found for city: chokurdakh    city id: 2126123
# Processing record 172 for the city: kavieng
#      Record found for city: kavieng    city id: 2094342
# Processing record 173 for the city: golden
#      Record found for city: golden    city id: 5962582
# Processing record 174 for the city: athy
#      Record found for city: athy    city id: 2966837
# Processing record 175 for the city: hun
#      Record found for city: hun    city id: 2790471
# Processing record 176 for the city: benguela
#      Record found for city: benguela    city id: 3351663
# Processing record 177 for the city: kaitangata
#      Record found for city: kaitangata    city id: 2208248
# Processing record 178 for the city: beringovskiy
#      Record found for city: beringovskiy    city id: 2126710
# Processing record 179 for the city: illoqqortoormiut
#      No weather record found for city: illoqqortoormiut
# Processing record 180 for the city: thinadhoo
#      Record found for city: thinadhoo    city id: 1337610
# Processing record 181 for the city: harrison
#      Record found for city: harrison    city id: 4513805
# Processing record 182 for the city: puerto el triunfo
#      Record found for city: puerto el triunfo    city id: 3584003
# Processing record 183 for the city: valdez
#      Record found for city: valdez    city id: 5877389
# Processing record 184 for the city: westport
#      Record found for city: westport    city id: 2960970
# Processing record 185 for the city: half moon bay
#      Record found for city: half moon bay    city id: 5354943
# Processing record 186 for the city: tadine
#      Record found for city: tadine    city id: 2138285
# Processing record 187 for the city: montrose
#      Record found for city: montrose    city id: 2157161
# Processing record 188 for the city: altay
#      Record found for city: altay    city id: 1529651
# Processing record 189 for the city: korla
#      No weather record found for city: korla
# Processing record 190 for the city: mar del plata
#      Record found for city: mar del plata    city id: 3863379
# Processing record 191 for the city: macamic
#      Record found for city: macamic    city id: 6062563
# Processing record 192 for the city: kapoeta
#      No weather record found for city: kapoeta
# Processing record 193 for the city: priargunsk
#      Record found for city: priargunsk    city id: 2017646
# Processing record 194 for the city: jalu
#      Record found for city: jalu    city id: 86049
# Processing record 195 for the city: tuktoyaktuk
#      Record found for city: tuktoyaktuk    city id: 6170031
# Processing record 196 for the city: lichinga
#      Record found for city: lichinga    city id: 1043893
# Processing record 197 for the city: pokhara
#      Record found for city: pokhara    city id: 1282898
# Processing record 198 for the city: atikokan
#      Record found for city: atikokan    city id: 5888001
# Processing record 199 for the city: hermanus
#      Record found for city: hermanus    city id: 3366880
# Processing record 200 for the city: bambous virieux
#      Record found for city: bambous virieux    city id: 1106677
# Processing record 201 for the city: rikitea
#      Record found for city: rikitea    city id: 4030556
# Processing record 202 for the city: tukrah
#      No weather record found for city: tukrah
# Processing record 203 for the city: nagato
#      Record found for city: nagato    city id: 1899102
# Processing record 204 for the city: airai
#      Record found for city: airai    city id: 1651810
# Processing record 205 for the city: zalantun
#      Record found for city: zalantun    city id: 2033225
# Processing record 206 for the city: magway
#      Record found for city: magway    city id: 1312609
# Processing record 207 for the city: ternate
#      Record found for city: ternate    city id: 1682474
# Processing record 208 for the city: zhanaozen
#      Record found for city: zhanaozen    city id: 607610
# Processing record 209 for the city: asau
#      No weather record found for city: asau
# Processing record 210 for the city: tiksi
#      Record found for city: tiksi    city id: 2015306
# Processing record 211 for the city: sobolevo
#      Record found for city: sobolevo    city id: 525426
# Processing record 212 for the city: muslyumovo
#      Record found for city: muslyumovo    city id: 524183
# Processing record 213 for the city: margate
#      Record found for city: margate    city id: 2158744
# Processing record 214 for the city: san patricio
#      Record found for city: san patricio    city id: 3437029
# Processing record 215 for the city: dongkan
#      Record found for city: dongkan    city id: 1812427
# Processing record 216 for the city: akyab
#      No weather record found for city: akyab
# Processing record 217 for the city: ballina
#      Record found for city: ballina    city id: 2966778
# Processing record 218 for the city: hithadhoo
#      Record found for city: hithadhoo    city id: 1282256
# Processing record 219 for the city: kapaa
#      Record found for city: kapaa    city id: 5848280
# Processing record 220 for the city: kosa
#      Record found for city: kosa    city id: 544318
# Processing record 221 for the city: werda
#      Record found for city: werda    city id: 2810970
# Processing record 222 for the city: coari
#      Record found for city: coari    city id: 3664539
# Processing record 223 for the city: ust-karsk
#      Record found for city: ust-karsk    city id: 2013942
# Processing record 224 for the city: carpentras
#      Record found for city: carpentras    city id: 3028542
# Processing record 225 for the city: bilibino
#      Record found for city: bilibino    city id: 2126682
# Processing record 226 for the city: kazachinskoye
#      Record found for city: kazachinskoye    city id: 1504075
# Processing record 227 for the city: gorele
#      Record found for city: gorele    city id: 746565
# Processing record 228 for the city: severo-yeniseyskiy
#      Record found for city: severo-yeniseyskiy    city id: 1492566
# Processing record 229 for the city: agua verde
#      Record found for city: agua verde    city id: 4019219
# Processing record 230 for the city: tezu
#      Record found for city: tezu    city id: 1254709
# Processing record 231 for the city: cayenne
#      Record found for city: cayenne    city id: 3382160
# Processing record 232 for the city: shenjiamen
#      Record found for city: shenjiamen    city id: 1795632
# Processing record 233 for the city: chuy
#      Record found for city: chuy    city id: 3443061
# Processing record 234 for the city: raudeberg
#      Record found for city: raudeberg    city id: 3146487
# Processing record 235 for the city: darnah
#      Record found for city: darnah    city id: 87205
# Processing record 236 for the city: la ronge
#      Record found for city: la ronge    city id: 6050066
# Processing record 237 for the city: mys shmidta
#      No weather record found for city: mys shmidta
# Processing record 238 for the city: nouadhibou
#      Record found for city: nouadhibou    city id: 2377457
# Processing record 239 for the city: joson
#      Record found for city: joson    city id: 1718266
# Processing record 240 for the city: santa teresa
#      Record found for city: santa teresa    city id: 3627047
# Processing record 241 for the city: mega
#      Record found for city: mega    city id: 331259
# Processing record 242 for the city: charyshskoye
#      Record found for city: charyshskoye    city id: 1508427
# Processing record 243 for the city: manzhouli
#      Record found for city: manzhouli    city id: 2035836
# Processing record 244 for the city: voghera
#      Record found for city: voghera    city id: 3163995
# Processing record 245 for the city: sarkand
#      Record found for city: sarkand    city id: 1519691
# Processing record 246 for the city: doha
#      Record found for city: doha    city id: 290030
# Processing record 247 for the city: inirida
#      Record found for city: inirida    city id: 3671450
# Processing record 248 for the city: aksu
#      Record found for city: aksu    city id: 1524298
# Processing record 249 for the city: verkhoyansk
#      Record found for city: verkhoyansk    city id: 2013465
# Processing record 250 for the city: floro
#      Record found for city: floro    city id: 3156980
# Processing record 251 for the city: sivas
#      Record found for city: sivas    city id: 300617
# Processing record 252 for the city: poum
#      Record found for city: poum    city id: 787487
# Processing record 253 for the city: bull savanna
#      Record found for city: bull savanna    city id: 3491161
# Processing record 254 for the city: savannah bight
#      Record found for city: savannah bight    city id: 3601402
# Processing record 255 for the city: moranbah
#      Record found for city: moranbah    city id: 6533368
# Processing record 256 for the city: padre bernardo
#      No weather record found for city: padre bernardo
# Processing record 257 for the city: moron
#      Record found for city: moron    city id: 3631878
# Processing record 258 for the city: castro
#      Record found for city: castro    city id: 3896218
# Processing record 259 for the city: okhotsk
#      Record found for city: okhotsk    city id: 2122605
# Processing record 260 for the city: shimoda
#      Record found for city: shimoda    city id: 1852357
# Processing record 261 for the city: coahuayana
#      Record found for city: coahuayana    city id: 3981460
# Processing record 262 for the city: panama city
#      Record found for city: panama city    city id: 4167694
# Processing record 263 for the city: provideniya
#      Record found for city: provideniya    city id: 4031574
# Processing record 264 for the city: solnechnyy
#      Record found for city: solnechnyy    city id: 2016307
# Processing record 265 for the city: cherskiy
#      Record found for city: cherskiy    city id: 2126199
# Processing record 266 for the city: high level
#      Record found for city: high level    city id: 5975004
# Processing record 267 for the city: hvide sande
#      Record found for city: hvide sande    city id: 2619537
# Processing record 268 for the city: gizycko
#      Record found for city: gizycko    city id: 772195
# Processing record 269 for the city: turochak
#      Record found for city: turochak    city id: 1488920
# Processing record 270 for the city: milkovo
#      Record found for city: milkovo    city id: 727030
# Processing record 271 for the city: lagoa
#      Record found for city: lagoa    city id: 2267254
# Processing record 272 for the city: bargal
#      No weather record found for city: bargal
# Processing record 273 for the city: tuatapere
#      Record found for city: tuatapere    city id: 2180815
# Processing record 274 for the city: wamba
#      Record found for city: wamba    city id: 204318
# Processing record 275 for the city: alofi
#      Record found for city: alofi    city id: 4036284
# Processing record 276 for the city: grand river south east
#      No weather record found for city: grand river south east
# Processing record 277 for the city: acapulco
#      Record found for city: acapulco    city id: 3533462
# Processing record 278 for the city: puerto del rosario
#      Record found for city: puerto del rosario    city id: 2512186
# Processing record 279 for the city: kingori
#      Record found for city: kingori    city id: 157268
# Processing record 280 for the city: remedios
#      Record found for city: remedios    city id: 3542455
# Processing record 281 for the city: fourmies
#      Record found for city: fourmies    city id: 3017512
# Processing record 282 for the city: lovozero
#      Record found for city: lovozero    city id: 533933
# Processing record 283 for the city: atbasar
#      Record found for city: atbasar    city id: 1526038
# Processing record 284 for the city: helong
#      Record found for city: helong    city id: 1808534
# Processing record 285 for the city: karkaralinsk
#      No weather record found for city: karkaralinsk
# Processing record 286 for the city: quatre cocos
#      Record found for city: quatre cocos    city id: 1106643
# Processing record 287 for the city: saint-philippe
#      Record found for city: saint-philippe    city id: 6138908
# Processing record 288 for the city: kieta
#      Record found for city: kieta    city id: 2094027
# Processing record 289 for the city: berdigestyakh
#      Record found for city: berdigestyakh    city id: 2026861
# Processing record 290 for the city: tilichiki
#      Record found for city: tilichiki    city id: 2120591
# Processing record 291 for the city: abu kamal
#      Record found for city: abu kamal    city id: 174448
# Processing record 292 for the city: hirado
#      Record found for city: hirado    city id: 1862555
# Processing record 293 for the city: port lincoln
#      Record found for city: port lincoln    city id: 2063036
# Processing record 294 for the city: arraial do cabo
#      Record found for city: arraial do cabo    city id: 3471451
# Processing record 295 for the city: marang
#      No weather record found for city: marang
# Processing record 296 for the city: zarya
#      Record found for city: zarya    city id: 840877
# Processing record 297 for the city: kamenka
#      Record found for city: kamenka    city id: 553725
# Processing record 298 for the city: nome
#      Record found for city: nome    city id: 4732862
# Processing record 299 for the city: umm lajj
#      Record found for city: umm lajj    city id: 100926
# Processing record 300 for the city: visby
#      Record found for city: visby    city id: 2662689
# Processing record 301 for the city: labuhan
#      Record found for city: labuhan    city id: 1641899
# Processing record 302 for the city: okha
#      Record found for city: okha    city id: 2122614
# Processing record 303 for the city: arinos
#      Record found for city: arinos    city id: 3471522
# Processing record 304 for the city: mandalgovi
#      Record found for city: mandalgovi    city id: 2030065
# Processing record 305 for the city: bolshiye klyuchishchi
#      No weather record found for city: bolshiye klyuchishchi
# Processing record 306 for the city: berlevag
#      Record found for city: berlevag    city id: 780687
# Processing record 307 for the city: karratha
#      Record found for city: karratha    city id: 6620339
# Processing record 308 for the city: hambantota
#      Record found for city: hambantota    city id: 1244926
# Processing record 309 for the city: la paz
#      Record found for city: la paz    city id: 4000900
# Processing record 310 for the city: najran
#      Record found for city: najran    city id: 103630
# Processing record 311 for the city: quelimane
#      Record found for city: quelimane    city id: 1028434
# Processing record 312 for the city: lebu
#      Record found for city: lebu    city id: 344979
# Processing record 313 for the city: preobrazhenskaya
#      No weather record found for city: preobrazhenskaya
# Processing record 314 for the city: tumannyy
#      No weather record found for city: tumannyy
# Processing record 315 for the city: bardiyah
#      No weather record found for city: bardiyah
# Processing record 316 for the city: kamenskoye
#      No weather record found for city: kamenskoye
# Processing record 317 for the city: gushikawa
#      Record found for city: gushikawa    city id: 1863495
# Processing record 318 for the city: tutoia
#      Record found for city: tutoia    city id: 3385899
# Processing record 319 for the city: kawhia
#      Record found for city: kawhia    city id: 2185537
# Processing record 320 for the city: argentan
#      Record found for city: argentan    city id: 3037051
# Processing record 321 for the city: ulladulla
#      Record found for city: ulladulla    city id: 2145554
# Processing record 322 for the city: manadhoo
#      Record found for city: manadhoo    city id: 1337618
# Processing record 323 for the city: agva
#      No weather record found for city: agva
# Processing record 324 for the city: nanma
#      Record found for city: nanma    city id: 1803546
# Processing record 325 for the city: leh
#      Record found for city: leh    city id: 1264976
# Processing record 326 for the city: araouane
#      Record found for city: araouane    city id: 2460954
# Processing record 327 for the city: cape coast
#      Record found for city: cape coast    city id: 2302357
# Processing record 328 for the city: wani
#      Record found for city: wani    city id: 1252960
# Processing record 329 for the city: fuling
#      Record found for city: fuling    city id: 1810979
# Processing record 330 for the city: grand gaube
#      Record found for city: grand gaube    city id: 934479
# Processing record 331 for the city: the valley
#      Record found for city: the valley    city id: 3573374
# Processing record 332 for the city: esperance
#      Record found for city: esperance    city id: 3573739
# Processing record 333 for the city: teya
#      Record found for city: teya    city id: 3526662
# Processing record 334 for the city: ambulu
#      Record found for city: ambulu    city id: 1621313
# Processing record 335 for the city: aklavik
#      Record found for city: aklavik    city id: 5882953
# Processing record 336 for the city: salalah
#      Record found for city: salalah    city id: 286621
# Processing record 337 for the city: russell
#      Record found for city: russell    city id: 3844421
# Processing record 338 for the city: doba
#      Record found for city: doba    city id: 2433437
# Processing record 339 for the city: sambava
#      Record found for city: sambava    city id: 1056899
# Processing record 340 for the city: yabrud
#      Record found for city: yabrud    city id: 162627
# Processing record 341 for the city: vestmannaeyjar
#      Record found for city: vestmannaeyjar    city id: 3412093
# Processing record 342 for the city: cascais
#      Record found for city: cascais    city id: 2269594
# Processing record 343 for the city: svetlogorsk
#      Record found for city: svetlogorsk    city id: 584051
# Processing record 344 for the city: vao
#      Record found for city: vao    city id: 588365
# Processing record 345 for the city: dori
#      Record found for city: dori    city id: 2361082
# Processing record 346 for the city: dien bien
#      No weather record found for city: dien bien
# Processing record 347 for the city: along
#      Record found for city: along    city id: 1278969
# Processing record 348 for the city: dali
#      Record found for city: dali    city id: 1814093
# Processing record 349 for the city: yenagoa
#      Record found for city: yenagoa    city id: 2318123
# Processing record 350 for the city: leshukonskoye
#      Record found for city: leshukonskoye    city id: 535839
# Processing record 351 for the city: clyde river
#      Record found for city: clyde river    city id: 5924351
# Processing record 352 for the city: belaya gora
#      Record found for city: belaya gora    city id: 2126785
# Processing record 353 for the city: port hedland
#      Record found for city: port hedland    city id: 2063042
# Processing record 354 for the city: cidreira
#      Record found for city: cidreira    city id: 3466165
# Processing record 355 for the city: kisangani
#      Record found for city: kisangani    city id: 212730
# Processing record 356 for the city: barcelona
#      Record found for city: barcelona    city id: 3128760
# Processing record 357 for the city: ixtapa
#      Record found for city: ixtapa    city id: 4004293
# Processing record 358 for the city: paamiut
#      Record found for city: paamiut    city id: 3421193
# Processing record 359 for the city: nanortalik
#      Record found for city: nanortalik    city id: 3421765
# Processing record 360 for the city: paka
#      Record found for city: paka    city id: 3190586
# Processing record 361 for the city: vostok
#      Record found for city: vostok    city id: 2013279
# Processing record 362 for the city: novolabinskaya
#      Record found for city: novolabinskaya    city id: 518652
# Processing record 363 for the city: kulu
#      Record found for city: kulu    city id: 206362
# Processing record 364 for the city: marsaxlokk
#      Record found for city: marsaxlokk    city id: 2562247
# Processing record 365 for the city: hami
#      Record found for city: hami    city id: 1529484
# Processing record 366 for the city: kerema
#      Record found for city: kerema    city id: 2094144
# Processing record 367 for the city: ahipara
#      Record found for city: ahipara    city id: 2194098
# Processing record 368 for the city: deer lake
#      Record found for city: deer lake    city id: 5937252
# Processing record 369 for the city: ouadda
#      Record found for city: ouadda    city id: 236901
# Processing record 370 for the city: batagay-alyta
#      Record found for city: batagay-alyta    city id: 2027042
# Processing record 371 for the city: turayf
#      Record found for city: turayf    city id: 101312
# Processing record 372 for the city: belmonte
#      Record found for city: belmonte    city id: 8010472
# Processing record 373 for the city: luanda
#      Record found for city: luanda    city id: 2240449
# Processing record 374 for the city: nassau
#      Record found for city: nassau    city id: 2851077
# Processing record 375 for the city: paragominas
#      Record found for city: paragominas    city id: 3393106
# Processing record 376 for the city: ban tak
#      Record found for city: ban tak    city id: 1154677
# Processing record 377 for the city: bafq
#      Record found for city: bafq    city id: 142255
# Processing record 378 for the city: lethem
#      Record found for city: lethem    city id: 3379316
# Processing record 379 for the city: cheney
#      Record found for city: cheney    city id: 5789856
# Processing record 380 for the city: luderitz
#      Record found for city: luderitz    city id: 3355672
# Processing record 381 for the city: oktyabrskoye
#      Record found for city: oktyabrskoye    city id: 1511846
# Processing record 382 for the city: longyearbyen
#      Record found for city: longyearbyen    city id: 2729907
# Processing record 383 for the city: codrington
#      Record found for city: codrington    city id: 2160063
# Processing record 384 for the city: faanui
#      Record found for city: faanui    city id: 4034551
# Processing record 385 for the city: arkhara
#      Record found for city: arkhara    city id: 2027487
# Processing record 386 for the city: pringsewu
#      Record found for city: pringsewu    city id: 1630639
# Processing record 387 for the city: buraydah
#      Record found for city: buraydah    city id: 107304
# Processing record 388 for the city: honningsvag
#      Record found for city: honningsvag    city id: 779554
# Processing record 389 for the city: mahdalynivka
#      Record found for city: mahdalynivka    city id: 702356
# Processing record 390 for the city: tsihombe
#      No weather record found for city: tsihombe
# Processing record 391 for the city: kembe
#      No weather record found for city: kembe
# Processing record 392 for the city: panzhihua
#      Record found for city: panzhihua    city id: 6929460
# Processing record 393 for the city: zaozerne
#      Record found for city: zaozerne    city id: 702421
# Processing record 394 for the city: duz
#      No weather record found for city: duz
# Processing record 395 for the city: armizonskoye
#      Record found for city: armizonskoye    city id: 1511382
# Processing record 396 for the city: aktash
#      No weather record found for city: aktash
# Processing record 397 for the city: muli
#      Record found for city: muli    city id: 1256929
# Processing record 398 for the city: rockland
#      Record found for city: rockland    city id: 4948924
# Processing record 399 for the city: kruisfontein
#      Record found for city: kruisfontein    city id: 986717
# Processing record 400 for the city: cabo san lucas
#      Record found for city: cabo san lucas    city id: 3985710
# Processing record 401 for the city: lubao
#      Record found for city: lubao    city id: 1705441
# Processing record 402 for the city: bichura
#      Record found for city: bichura    city id: 2026708
# Processing record 403 for the city: buenavista
#      Record found for city: buenavista    city id: 3688433
# Processing record 404 for the city: zyryanka
#      Record found for city: zyryanka    city id: 2119283
# Processing record 405 for the city: sumbawanga
#      Record found for city: sumbawanga    city id: 149703
# Processing record 406 for the city: hokitika
#      Record found for city: hokitika    city id: 2206894
# Processing record 407 for the city: curuca
#      Record found for city: curuca    city id: 3663145
# Processing record 408 for the city: avarua
#      Record found for city: avarua    city id: 4035715
# Processing record 409 for the city: flin flon
#      Record found for city: flin flon    city id: 5954718
# Processing record 410 for the city: ust-maya
#      Record found for city: ust-maya    city id: 2013918
# Processing record 411 for the city: rudsar
#      Record found for city: rudsar    city id: 118191
# Processing record 412 for the city: hervey bay
#      Record found for city: hervey bay    city id: 2146219
# Processing record 413 for the city: marsa matruh
#      Record found for city: marsa matruh    city id: 352733
# Processing record 414 for the city: quetta
#      Record found for city: quetta    city id: 1167528
# Processing record 415 for the city: ancud
#      Record found for city: ancud    city id: 3899695
# Processing record 416 for the city: hirara
#      Record found for city: hirara    city id: 1862505
# Processing record 417 for the city: sept-iles
#      Record found for city: sept-iles    city id: 6144312
# Processing record 418 for the city: andevoranto
#      No weather record found for city: andevoranto
# Processing record 419 for the city: miram shah
#      Record found for city: miram shah    city id: 1170367
# Processing record 420 for the city: nynashamn
#      Record found for city: nynashamn    city id: 2687636
# Processing record 421 for the city: nuuk
#      Record found for city: nuuk    city id: 3421319
# Processing record 422 for the city: awjilah
#      Record found for city: awjilah    city id: 88533
# Processing record 423 for the city: pemangkat
#      No weather record found for city: pemangkat
# Processing record 424 for the city: gwadar
#      Record found for city: gwadar    city id: 1177446
# Processing record 425 for the city: fairbanks
#      Record found for city: fairbanks    city id: 5861897
# Processing record 426 for the city: dzhebariki-khaya
#      Record found for city: dzhebariki-khaya    city id: 2024626
# Processing record 427 for the city: bosconia
#      Record found for city: bosconia    city id: 3775850
# Processing record 428 for the city: marzuq
#      Record found for city: marzuq    city id: 72181
# Processing record 429 for the city: moree
#      Record found for city: moree    city id: 2156927
# Processing record 430 for the city: warqla
#      No weather record found for city: warqla
# Processing record 431 for the city: mayo
#      Record found for city: mayo    city id: 6068416
# Processing record 432 for the city: yar-sale
#      Record found for city: yar-sale    city id: 1486321
# Processing record 433 for the city: manggar
#      Record found for city: manggar    city id: 1636426
# Processing record 434 for the city: dianopolis
#      No weather record found for city: dianopolis
# Processing record 435 for the city: agucadoura
#      Record found for city: agucadoura    city id: 2743298
# Processing record 436 for the city: boa vista
#      Record found for city: boa vista    city id: 3664980
# Processing record 437 for the city: djougou
#      Record found for city: djougou    city id: 2394560
# Processing record 438 for the city: katra
#      Record found for city: katra    city id: 1267448
# Processing record 439 for the city: lasa
#      Record found for city: lasa    city id: 146639
# Processing record 440 for the city: agirish
#      Record found for city: agirish    city id: 1512101
# Processing record 441 for the city: narsaq
#      Record found for city: narsaq    city id: 3421719
# Processing record 442 for the city: dharchula
#      Record found for city: dharchula    city id: 1272864
# Processing record 443 for the city: shelburne
#      Record found for city: shelburne    city id: 6145890
# Processing record 444 for the city: rungata
#      No weather record found for city: rungata
# Processing record 445 for the city: buta
#      Record found for city: buta    city id: 217570
# Processing record 446 for the city: saleaula
#      No weather record found for city: saleaula
# Processing record 447 for the city: ust-kamchatsk
#      No weather record found for city: ust-kamchatsk
# Processing record 448 for the city: launceston
#      Record found for city: launceston    city id: 2160517
# Processing record 449 for the city: hamilton
#      Record found for city: hamilton    city id: 3573197
# Processing record 450 for the city: port hardy
#      Record found for city: port hardy    city id: 6111862
# Processing record 451 for the city: kargasok
#      Record found for city: kargasok    city id: 1504382
# Processing record 452 for the city: bilma
#      Record found for city: bilma    city id: 2446796
# Processing record 453 for the city: biak
#      Record found for city: biak    city id: 1637001
# Processing record 454 for the city: aden
#      Record found for city: aden    city id: 415189
# Processing record 455 for the city: lompoc
#      Record found for city: lompoc    city id: 5367788
# Processing record 456 for the city: klaksvik
#      Record found for city: klaksvik    city id: 2618795
# Processing record 457 for the city: barawe
#      No weather record found for city: barawe
# Processing record 458 for the city: waterloo
#      Record found for city: waterloo    city id: 6176823
# Processing record 459 for the city: petaluma
#      Record found for city: petaluma    city id: 5382232
# Processing record 460 for the city: sawakin
#      Record found for city: sawakin    city id: 367544
# Processing record 461 for the city: dargaville
#      Record found for city: dargaville    city id: 2191911
# Processing record 462 for the city: bur gabo
#      No weather record found for city: bur gabo
# Processing record 463 for the city: mecca
#      Record found for city: mecca    city id: 104515
# Processing record 464 for the city: pudozh
#      Record found for city: pudozh    city id: 504269
# Processing record 465 for the city: redmond
#      Record found for city: redmond    city id: 5808079
# Processing record 466 for the city: palasa
#      No weather record found for city: palasa
# Processing record 467 for the city: mount isa
#      Record found for city: mount isa    city id: 2065594
# Processing record 468 for the city: vila velha
#      Record found for city: vila velha    city id: 6320062
# Processing record 469 for the city: mikun
#      Record found for city: mikun    city id: 526600
# Processing record 470 for the city: sovetskaya
#      Record found for city: sovetskaya    city id: 490065
# Processing record 471 for the city: limoux
#      Record found for city: limoux    city id: 2998264
# Processing record 472 for the city: vanimo
#      Record found for city: vanimo    city id: 2084442
# Processing record 473 for the city: dicabisagan
#      Record found for city: dicabisagan    city id: 1715015
# Processing record 474 for the city: attawapiskat
#      No weather record found for city: attawapiskat
# Processing record 475 for the city: phonhong
# ...
# Processing record 593 for the city: wukari
#      Record found for city: wukari    city id: 2318921
# Processing record 594 for the city: itoman
#      Record found for city: itoman    city id: 1861280
# Processing record 595 for the city: saint-francois
#      Record found for city: saint-francois    city id: 2980080
# Processing record 596 for the city: marienburg
#      Record found for city: marienburg    city id: 2803461
# Processing record 597 for the city: abonnema
#      Record found for city: abonnema    city id: 2324433
# Processing record 598 for the city: dalbandin
#      Record found for city: dalbandin    city id: 1180729
# Processing record 599 for the city: tabas
#      Record found for city: tabas    city id: 113659
# Processing record 600 for the city: senno
#      Record found for city: senno    city id: 554873
# Processing record 601 for the city: gazli
#      Record found for city: gazli    city id: 1513990
# Processing record 602 for the city: mujiayingzi
#      Record found for city: mujiayingzi    city id: 2035707
# Processing record 603 for the city: cape elizabeth
#      No weather record found for city: cape elizabeth
# Processing record 604 for the city: beisfjord
#      Record found for city: beisfjord    city id: 3144987
# Processing record 605 for the city: sao filipe
#      Record found for city: sao filipe    city id: 3374210
# Processing record 606 for the city: fukuma
#      Record found for city: fukuma    city id: 1863978
# Processing record 607 for the city: torbay
#      Record found for city: torbay    city id: 6167817
# Processing record 608 for the city: kamaishi
#      Record found for city: kamaishi    city id: 2112444
# Processing record 609 for the city: huilong
#      Record found for city: huilong    city id: 1795424
# Processing record 610 for the city: luena
#      Record found for city: luena    city id: 3347719
# Processing record 611 for the city: batagay
#      Record found for city: batagay    city id: 2027044
# Processing record 612 for the city: franklin
#      Record found for city: franklin    city id: 4623560
# Processing record 613 for the city: trojes
#      Record found for city: trojes    city id: 783493
# Processing record 614 for the city: mehamn
#      Record found for city: mehamn    city id: 778707
# Processing record 615 for the city: hamadan
#      No weather record found for city: hamadan
# Processing record 616 for the city: birao
#      Record found for city: birao    city id: 240210
# Processing record 617 for the city: gigmoto
#      Record found for city: gigmoto    city id: 1712961
# Processing record 618 for the city: darhan
#      Record found for city: darhan    city id: 2031964
# Processing record 619 for the city: porto velho
#      Record found for city: porto velho    city id: 3662762
# Processing record 620 for the city: maniitsoq
#      Record found for city: maniitsoq    city id: 3421982
# Processing record 621 for the city: tobolsk
#      Record found for city: tobolsk    city id: 1489530
# Processing record 622 for the city: vila
#      Record found for city: vila    city id: 3164565
# Processing record 623 for the city: villaviciosa
#      Record found for city: villaviciosa    city id: 3104707
# Processing record 624 for the city: maniwaki
#      Record found for city: maniwaki    city id: 6065262
# Processing record 625 for the city: coihaique
#      Record found for city: coihaique    city id: 3894426
# Processing record 626 for the city: beyneu
#      Record found for city: beyneu    city id: 610298
# Processing record 627 for the city: yaan
#      Record found for city: yaan    city id: 2338660
# Processing record 628 for the city: lichtenburg
#      Record found for city: lichtenburg    city id: 982899
# Processing record 629 for the city: astana
#      Record found for city: astana    city id: 1526273
# Processing record 630 for the city: nago
#      Record found for city: nago    city id: 3172402
# Processing record 631 for the city: san benedetto del tronto
#      Record found for city: san benedetto del tronto    city id: 3168550
# Processing record 632 for the city: toyooka
#      Record found for city: toyooka    city id: 1849831
# Processing record 633 for the city: vestmanna
#      Record found for city: vestmanna    city id: 2610343
# Processing record 634 for the city: ginir
#      Record found for city: ginir    city id: 336454
# Processing record 635 for the city: hovd
#      Record found for city: hovd    city id: 7626384
# Processing record 636 for the city: tobol
#      Record found for city: tobol    city id: 2725123
# Processing record 637 for the city: fagernes
#      Record found for city: fagernes    city id: 3157897
# Processing record 638 for the city: port hawkesbury
#      Record found for city: port hawkesbury    city id: 6111867
# Processing record 639 for the city: sabha
#      Record found for city: sabha    city id: 2212775
# Processing record 640 for the city: ornskoldsvik
#      Record found for city: ornskoldsvik    city id: 2686469
# Processing record 641 for the city: vanavara
#      Record found for city: vanavara    city id: 2013727
# Processing record 642 for the city: santa maria
#      Record found for city: santa maria    city id: 3450083
# Processing record 643 for the city: andenes
#      No weather record found for city: andenes
# Processing record 644 for the city: te anau
#      Record found for city: te anau    city id: 2181625
# Processing record 645 for the city: carikar
#      No weather record found for city: carikar
# Processing record 646 for the city: norfolk
#      Record found for city: norfolk    city id: 4776222
# Processing record 647 for the city: port-gentil
#      Record found for city: port-gentil    city id: 2396518
# Processing record 648 for the city: caernarfon
#      Record found for city: caernarfon    city id: 2654092
# Processing record 649 for the city: lesogorskiy
#      Record found for city: lesogorskiy    city id: 535670
# Processing record 650 for the city: kirkwall
#      Record found for city: kirkwall    city id: 2645198
# Processing record 651 for the city: buchmany
#      Record found for city: buchmany    city id: 698943
# Processing record 652 for the city: langham
#      Record found for city: langham    city id: 6049403
# Processing record 653 for the city: creel
#      Record found for city: creel    city id: 4012593
# Processing record 654 for the city: shirokiy
#      Record found for city: shirokiy    city id: 512255
# Processing record 655 for the city: chilca
#      Record found for city: chilca    city id: 3934055
# Processing record 656 for the city: sola
#      Record found for city: sola    city id: 3137942
# Processing record 657 for the city: ardistan
#      No weather record found for city: ardistan
# Processing record 658 for the city: kango
#      Record found for city: kango    city id: 2400682
# Processing record 659 for the city: taganak
#      Record found for city: taganak    city id: 1684606
# Processing record 660 for the city: itatskiy
#      Record found for city: itatskiy    city id: 1505383
# Processing record 661 for the city: gorno-altaysk
#      Record found for city: gorno-altaysk    city id: 1506271
# Processing record 662 for the city: arlit
#      Record found for city: arlit    city id: 2447513
# Processing record 663 for the city: lavrentiya
#      Record found for city: lavrentiya    city id: 4031637
# Processing record 664 for the city: derbent
#      Record found for city: derbent    city id: 566532
# Processing record 665 for the city: burriana
#      Record found for city: burriana    city id: 2520709
# Processing record 666 for the city: saldanha
#      Record found for city: saldanha    city id: 2737599
# Processing record 667 for the city: chara
#      Record found for city: chara    city id: 262462
# Processing record 668 for the city: khandyga
#      Record found for city: khandyga    city id: 2022773
# Processing record 669 for the city: haines junction
#      Record found for city: haines junction    city id: 5969025
# Processing record 670 for the city: tagusao
#      Record found for city: tagusao    city id: 1684245
# Processing record 671 for the city: temaraia
#      No weather record found for city: temaraia
# Processing record 672 for the city: kimberley
#      Record found for city: kimberley    city id: 990930
# Processing record 673 for the city: nemuro
#      Record found for city: nemuro    city id: 2128975
# Processing record 674 for the city: pak phanang
#      Record found for city: pak phanang    city id: 1608033
# Processing record 675 for the city: tarudant
#      No weather record found for city: tarudant
# Processing record 676 for the city: san vicente
#      Record found for city: san vicente    city id: 3583178
# Processing record 677 for the city: chagda
#      No weather record found for city: chagda
# Processing record 678 for the city: kodinar
#      Record found for city: kodinar    city id: 1266397
# Processing record 679 for the city: ahtopol
#      Record found for city: ahtopol    city id: 729125
# Processing record 680 for the city: dunedin
#      Record found for city: dunedin    city id: 2191562
# Processing record 681 for the city: rorvik
#      Record found for city: rorvik    city id: 3141310
# Processing record 682 for the city: qui nhon
#      No weather record found for city: qui nhon
# Processing record 683 for the city: santa cruz de la palma
#      Record found for city: santa cruz de la palma    city id: 2511180
# Processing record 684 for the city: la union
#      Record found for city: la union    city id: 3593500
# Processing record 685 for the city: ayagoz
#      Record found for city: ayagoz    city id: 1525988
# Processing record 686 for the city: bambanglipuro
#      Record found for city: bambanglipuro    city id: 1650434
# Processing record 687 for the city: policoro
#      Record found for city: policoro    city id: 6541279
# Processing record 688 for the city: juba
#      Record found for city: juba    city id: 587450
# Processing record 689 for the city: teknaf
#      Record found for city: teknaf    city id: 1185095
# Processing record 690 for the city: nioro
#      Record found for city: nioro    city id: 2413070
# Processing record 691 for the city: tripoli
#      Record found for city: tripoli    city id: 252601
# Processing record 692 for the city: farafangana
#      Record found for city: farafangana    city id: 1065158
# Processing record 693 for the city: misratah
#      Record found for city: misratah    city id: 2214846
# Processing record 694 for the city: mangan
#      Record found for city: mangan    city id: 1263776
# Processing record 695 for the city: port-de-bouc
#      Record found for city: port-de-bouc    city id: 6447156
# Processing record 696 for the city: ilulissat
#      Record found for city: ilulissat    city id: 3423146
# Processing record 697 for the city: varkkallai
#      Record found for city: varkkallai    city id: 1253392
# Processing record 698 for the city: svetlaya
#      Record found for city: svetlaya    city id: 2015852
# Processing record 699 for the city: rovereto
#      Record found for city: rovereto    city id: 6539916
# Processing record 700 for the city: malwan
#      No weather record found for city: malwan
# Processing record 701 for the city: japura
#      Record found for city: japura    city id: 1642773
# Processing record 702 for the city: matara
#      Record found for city: matara    city id: 3948642
# Processing record 703 for the city: sakakah
#      No weather record found for city: sakakah
# Processing record 704 for the city: beba
#      Record found for city: beba    city id: 3543961
# Processing record 705 for the city: puerto escondido
#      Record found for city: puerto escondido    city id: 3520994
# Processing record 706 for the city: sulangan
#      Record found for city: sulangan    city id: 1685422
# Processing record 707 for the city: longyan
#      Record found for city: longyan    city id: 1802276
# Processing record 708 for the city: uribia
#      Record found for city: uribia    city id: 3666409
# Processing record 709 for the city: shingu
#      Record found for city: shingu    city id: 1847947
# Processing record 710 for the city: mashhad
#      Record found for city: mashhad    city id: 124665
# Processing record 711 for the city: longkou
#      Record found for city: longkou    city id: 1802550
# Processing record 712 for the city: grootfontein
#      Record found for city: grootfontein    city id: 3357114
# Processing record 713 for the city: kununurra
#      Record found for city: kununurra    city id: 2068110
# Processing record 714 for the city: hearst
#      Record found for city: hearst    city id: 5973108
# Processing record 715 for the city: paoua
#      Record found for city: paoua    city id: 2383523
# Processing record 716 for the city: jupiter
#      Record found for city: jupiter    city id: 4160610
# Processing record 717 for the city: weihai
#      Record found for city: weihai    city id: 1791673
# Processing record 718 for the city: asosa
#      Record found for city: asosa    city id: 343292
# Processing record 719 for the city: chumphon
#      Record found for city: chumphon    city id: 1153557
# Processing record 720 for the city: port macquarie
#      Record found for city: port macquarie    city id: 2152659
# Processing record 721 for the city: dabakala
#      Record found for city: dabakala    city id: 2290609
# Processing record 722 for the city: luganville
#      Record found for city: luganville    city id: 2136150
# Processing record 723 for the city: bogorodskoye
#      Record found for city: bogorodskoye    city id: 2126638
# Processing record 724 for the city: piopio
#      Record found for city: piopio    city id: 3874453
# Processing record 725 for the city: bathsheba
#      Record found for city: bathsheba    city id: 3374083
# Processing record 726 for the city: babanusah
#      No weather record found for city: babanusah
# Processing record 727 for the city: itarema
#      Record found for city: itarema    city id: 3393692
# Processing record 728 for the city: navabad
#      No weather record found for city: navabad
# Processing record 729 for the city: coldwater
#      Record found for city: coldwater    city id: 4989266
# Processing record 730 for the city: algiers
#      Record found for city: algiers    city id: 4335045
# Processing record 731 for the city: portland
#      Record found for city: portland    city id: 5746545
# Processing record 732 for the city: oksfjord
#      Record found for city: oksfjord    city id: 778362
# Processing record 733 for the city: horta
#      Record found for city: horta    city id: 3128760
# Processing record 734 for the city: havelock
#      Record found for city: havelock    city id: 4470244
# Processing record 735 for the city: shahreza
#      Record found for city: shahreza    city id: 417594
# Processing record 736 for the city: chifeng
#      Record found for city: chifeng    city id: 2038067
# Processing record 737 for the city: tabuk
#      Record found for city: tabuk    city id: 1684803
# Processing record 738 for the city: ouesso
#      Record found for city: ouesso    city id: 2255564
# Processing record 739 for the city: fresnillo
#      Record found for city: fresnillo    city id: 4006163
# Processing record 740 for the city: krasnystaw
#      Record found for city: krasnystaw    city id: 767605
# Processing record 741 for the city: kemijarvi
#      No weather record found for city: kemijarvi
# Processing record 742 for the city: karaul
#      No weather record found for city: karaul
# Processing record 743 for the city: moose factory
#      Record found for city: moose factory    city id: 6078372
# Processing record 744 for the city: elk city
#      Record found for city: elk city    city id: 4535823
# Processing record 745 for the city: halalo
#      No weather record found for city: halalo
# Processing record 746 for the city: ellisras
#      Record found for city: ellisras    city id: 1005768
# Processing record 747 for the city: yuxia
#      Record found for city: yuxia    city id: 1785572
# Processing record 748 for the city: pangnirtung
#      Record found for city: pangnirtung    city id: 6096551
# Processing record 749 for the city: road town
#      Record found for city: road town    city id: 3577430
# Processing record 750 for the city: albion
#      Record found for city: albion    city id: 5062806
# ---------------------------------------
# End

# %%
#print(json.dumps(search_data[2], indent=4))
len(search_data)
# Out:
# 668

# %%
# Use list comprehension to gather necessary data series

lat_data = [data.get("coord").get("lat") for data in search_data]
lng_data = [data.get("coord").get("lon") for data in search_data]
temp_data = [data.get("main").get("temp") for data in search_data]
humid_data = [data.get("main").get("humidity") for data in search_data]
cloud_data =[data.get("clouds").get("all") for data in search_data]
wind_data = [data.get("wind").get("speed") for data in search_data]

# %%
# Create data frame with aggregated data
weather_data = pd.DataFrame({"cityName":cityList,
                            "country":countryList,
                            "lat":lat_data,
                            "lng":lng_data,
                            "temp":temp_data,
                            "humidity":humid_data,
                            "cloudiness":cloud_data,
                            "winds":wind_data})

# %%
# Change column order
weather_data = weather_data[["cityName","country","lat","lng","temp","humidity","cloudiness","winds"]]
weather_data.head()
# Out:
#        cityName country    lat     lng   temp  humidity  cloudiness  winds
# 0    wloszczowa      pl  50.85   19.97  62.60        95          68   7.63
# 1       tautira      pf -17.73 -149.15  82.40        69          75  10.29
# 2  saint george      bm  39.45   22.34  64.40        68          20   2.48
# 3      lorengau      pg  -2.02  147.27  79.25       100         100   2.04
# 4      victoria      sc   5.28  115.24  78.80        94          75   6.62

# %%
# Save weather data to csv file
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %%
# Latitude vs Max Temp
sns.regplot(x='lat',y='temp', data=weather_data, scatter = True, fit_reg=False)

# Add chart labels
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (F) ")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90)

# Save the figure
plt.savefig("Latitude_vs_MaxTemp.png")

# %%
# Latitude vs Humidity
sns.regplot(x='lat',y='humidity', data=weather_data, scatter = True, fit_reg=False)

# Add chart labels
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# %%
# Latitude vs Cloudiness
sns.regplot(x='lat',y='cloudiness', data=weather_data, scatter = True, fit_reg=False)

plt.title("City Latitude vs Cloudiness")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_Cloudiness.png")

# %%
# Latitude vs Wind Speed
sns.regplot(x='lat',y='winds', data=weather_data, scatter = True, fit_reg=False)

# Add chart labels
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
#plt.xlim(-90,90)

# Save the figure
plt.savefig("Latitude_vs_WindSpeed.png")
